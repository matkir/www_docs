# %%
import matplotlib.pyplot as plt
import locale
from numpy import *
aar=12*5 #ant mnd vi vil modelere 


solgte_prover=zeros(aar)
lisens_total=zeros(aar)
salg_av_modul_total=zeros(aar)




solgte_enheter=array([int(100*2**(i/12))  for i in range(aar)])

pris_per_modul=1000 #kr inntekt per modul (salgspris-innkjøpspris)
pris_per_prove=40 #kr inntekt per prove (salgspris-innkjøpspris)
prover= 365 #ant forventet salg per enhet per år
lisens_pris=1000 #kr per lisens per aar


print(solgte_enheter)
print("antall enheter solgt per mnd")


for i in range(aar):
    if i!=0:
        solgte_prover[i]=solgte_enheter[i]*prover*pris_per_prove+solgte_prover[i-1]
        lisens_total[i]=solgte_enheter[i]*lisens_pris+lisens_total[i-1]
        salg_av_modul_total[i]=solgte_enheter[i]*pris_per_modul
    else:
        solgte_prover[i]=solgte_enheter[i]*prover*pris_per_prove
        lisens_total[i]=solgte_enheter[i]*lisens_pris
        salg_av_modul_total[i]=solgte_enheter[i]*pris_per_modul
    



inntekt_per_aar=\
    salg_av_modul_total\
    +solgte_prover\
    +lisens_total
#pris per år er satt sammen av:
#salg av modul: Ant moduler solgt, dette er en engangssum
#solgte_prover: Hvor mange prøver solgt, gamle og nye kunder
#lisens_total: alle kunder 
    
    
plt.bar(linspace(1,aar,aar),inntekt_per_aar)
plt.xlabel('mnd')
plt.ylabel('inntekt [kr/år]')
plt.yscale('log')
plt.show()
for i in enumerate(inntekt_per_aar):
    print("mnd {0}\nTotal: {1:,} kr  \nEnheter {2}\n".format(i[0]+1,int(i[1]),solgte_enheter[i[0]]))
# Out:
# [ 100  105  112  118  125  133  141  149  158  168  178  188  200  211  224
#   237  251  266  282  299  317  336  356  377  400  423  448  475  503  533
#   565  599  634  672  712  755  800  847  897  951 1007 1067 1131 1198 1269
#  1345 1425 1510 1600 1695 1795 1902 2015 2135 2262 2397 2539 2690 2850 3020]
# antall enheter solgt per mnd
# mnd 1
# Total: 1,660,000 kr
# Enheter 100
#
# mnd 2
# Total: 3,303,000 kr
# Enheter 105
#
# mnd 3
# Total: 5,057,200 kr
# Enheter 112
#
# mnd 4
# Total: 6,904,000 kr
# Enheter 118
#
# mnd 5
# Total: 8,861,000 kr
# Enheter 125
#
# mnd 6
# Total: 10,943,800 kr
# Enheter 133
#
# mnd 7
# Total: 13,151,400 kr
# Enheter 141
#
# mnd 8
# Total: 15,483,800 kr
# Enheter 149
#
# mnd 9
# Total: 17,957,600 kr
# Enheter 158
#
# mnd 10
# Total: 20,588,400 kr
# Enheter 168
#
# mnd 11
# Total: 23,375,200 kr
# Enheter 178
#
# mnd 12
# Total: 26,318,000 kr
# Enheter 188
#
# mnd 13
# Total: 29,450,000 kr
# Enheter 200
#
# mnd 14
# Total: 32,752,600 kr
# Enheter 211
#
# mnd 15
# Total: 36,260,000 kr
# Enheter 224
#
# mnd 16
# Total: 39,970,200 kr
# Enheter 237
#
# mnd 17
# Total: 43,899,800 kr
# Enheter 251
#
# mnd 18
# Total: 48,064,400 kr
# Enheter 266
#
# mnd 19
# Total: 52,479,600 kr
# Enheter 282
#
# mnd 20
# Total: 57,161,000 kr
# Enheter 299
#
# mnd 21
# Total: 62,124,200 kr
# Enheter 317
#
# mnd 22
# Total: 67,384,800 kr
# Enheter 336
#
# mnd 23
# Total: 72,958,400 kr
# Enheter 356
#
# mnd 24
# Total: 78,860,600 kr
# Enheter 377
#
# mnd 25
# Total: 85,123,600 kr
# Enheter 400
#
# mnd 26
# Total: 91,745,400 kr
# Enheter 423
#
# mnd 27
# Total: 98,759,200 kr
# Enheter 448
#
# mnd 28
# Total: 106,196,200 kr
# Enheter 475
#
# mnd 29
# Total: 114,071,000 kr
# Enheter 503
#
# mnd 30
# Total: 122,415,800 kr
# Enheter 533
#
# mnd 31
# Total: 131,261,800 kr
# Enheter 565
#
# mnd 32
# Total: 140,640,200 kr
# Enheter 599
#
# mnd 33
# Total: 150,565,600 kr
# Enheter 634
#
# mnd 34
# Total: 161,086,800 kr
# Enheter 672
#
# mnd 35
# Total: 172,234,000 kr
# Enheter 712
#
# mnd 36
# Total: 184,055,000 kr
# Enheter 755
#
# mnd 37
# Total: 196,580,000 kr
# Enheter 800
#
# mnd 38
# Total: 209,840,200 kr
# Enheter 847
#
# mnd 39
# Total: 223,883,400 kr
# Enheter 897
#
# mnd 40
# Total: 238,773,000 kr
# Enheter 951
#
# mnd 41
# Total: 254,538,200 kr
# Enheter 1007
#
# mnd 42
# Total: 271,243,400 kr
# Enheter 1067
#
# mnd 43
# Total: 288,951,000 kr
# Enheter 1131
#
# mnd 44
# Total: 307,706,800 kr
# Enheter 1198
#
# mnd 45
# Total: 327,574,200 kr
# Enheter 1269
#
# mnd 46
# Total: 348,632,200 kr
# Enheter 1345
#
# mnd 47
# Total: 370,942,200 kr
# Enheter 1425
#
# mnd 48
# Total: 394,583,200 kr
# Enheter 1510
#
# mnd 49
# Total: 419,633,200 kr
# Enheter 1600
#
# mnd 50
# Total: 446,170,200 kr
# Enheter 1695
#
# mnd 51
# Total: 474,272,200 kr
# Enheter 1795
#
# mnd 52
# Total: 504,050,400 kr
# Enheter 1902
#
# mnd 53
# Total: 535,597,400 kr
# Enheter 2015
#
# mnd 54
# Total: 569,023,400 kr
# Enheter 2135
#
# mnd 55
# Total: 604,437,600 kr
# Enheter 2262
#
# mnd 56
# Total: 641,965,800 kr
# Enheter 2397
#
# mnd 57
# Total: 681,716,200 kr
# Enheter 2539
#
# mnd 58
# Total: 723,831,200 kr
# Enheter 2690
#
# mnd 59
# Total: 768,451,200 kr
# Enheter 2850
#
# mnd 60
# Total: 815,733,200 kr
# Enheter 3020
